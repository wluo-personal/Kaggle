# %%
import pandas as pd
import numpy as np

# %%
report = pd.read_csv('grid_search.csv')

# %%
report.sort_values(['ROC'], ascending=False)
# Out:
#          ROC  feature_fraction  learning_rate  max_depth  min_data_in_leaf  \
# 29  0.984858               0.6           0.03         -1              1999
# 53  0.984846               0.6           0.03         -1              1000
# 27  0.984806               0.7           0.03         -1              1999
# 41  0.984804               0.6           0.03         -1               100
# 51  0.984782               0.7           0.03         -1              1000
# 33  0.984728               0.7           0.03         -1               390
# 57  0.984723               0.7           0.03         -1              1999
# 16  0.984696               0.8           0.03         -1               190
# 24  0.984660               0.7           0.10         -1              1999
# 28  0.984655               0.8           0.03         -1              1999
# 50  0.984622               0.6           0.10         -1              1000
# ...
