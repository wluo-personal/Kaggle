# %%
import pandas as pd
import numpy as np

# %%
result = pd.read_csv('/home/kai/talkingdata/data/catboostgirdsearchparams-result.csv')

# %%
result.sort_values('ROC',ascending=False)
# Out:
#           ROC  depth  iterations  l2_leaf_reg  learning_rate  \
# 9    0.981386      9         254            9           0.15
# 175  0.981010      6         169           50           0.30
# 153  0.980660      9          89            9           0.30
# 190  0.000000      9           0           20           0.30
# 196  0.000000      6           0            6           0.15
# 195  0.000000      3           0           50           0.15
# 194  0.000000      3           0           20           0.15
# 193  0.000000      3           0            9           0.15
# 192  0.000000      3           0            6           0.15
# 191  0.000000      9           0           50           0.30
# 0    0.000000      3           0            6           0.15
# 189  0.000000      9           0            9           0.30
# 198  0.000000      6           0           20           0.15
# 188  0.000000      9           0            6           0.30
# ...
