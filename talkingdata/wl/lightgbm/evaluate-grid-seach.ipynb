# %%
import pandas as pd
import numpy as np

# %%
result =pd.read_csv('/home/kai/talkingdata/data/girdsearch-result.csv')

# %%
result.sort_values('roc', ascending=False)
# Out:
#     best_rount                                      drpcol       roc
# 10       150.0                                     channel  0.982161
# 22       110.0                          app_device_os_mean  0.982049
# 7        102.0                ip_device_os_countfromfuture  0.981986
# 25       114.0             ip_device_os_time2previousclick  0.981975
# 2        114.0              ip_app_device_os_countfrompast  0.981955
# 17        93.0                          ip_app_device_mean  0.981949
# 5        114.0            ip_app_device_os_countfromfuture  0.981942
# 3        100.0         ip_app_device_os_time2previousclick  0.981937
# 8        114.0                       ip_app_day_hour_count  0.981934
# 11       148.0                  ip_device_os_firsttimediff  0.981918
# 35       126.0                ip_app_device_time2nextclick  0.981916
# 6        106.0              ip_app_device_os_firsttimediff  0.981913
# 37       151.0                         attributed_timediff  0.981912
# ...

# %% [markdown]
# # Params

# %%
result_param =pd.read_csv('/home/kai/talkingdata/data/girdsearchparams-result.csv')

# %%
result_param.sort_values('ROC', ascending=False)
# Out:
#            ROC  bagging_fraction  feature_fraction  lambda_l2  learning_rate  \
# 398   0.982490               1.0               0.4          7            0.1
# 1345  0.982382               1.0               0.6          1            0.1
# 2198  0.982381               1.0               0.5         20            0.1
# 388   0.982336               0.8               0.4          7            0.1
# 1219  0.982286               0.9               0.7          9            0.1
# 1019  0.982285               0.9               0.7          9            0.1
# 968   0.982271               0.9               0.5          7            0.1
# 1321  0.982263               1.0               0.7          3            0.1
# 1711  0.982229               0.8               0.5         30            0.1
# 1679  0.982215               1.0               0.7         30            0.1
# 1602  0.982135               0.7               0.6         20            0.1
# ...
