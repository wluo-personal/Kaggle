# %%
import pandas as pd

PATH = '../data/'
train = pd.read_csv(PATH+'test_device.csv')
print(train.columns)
# Out:
# Index(['ip', 'app', 'device', 'os', 'channel', 'day', 'hour', 'timestamp',
#        'minute', 'second', 'intesthh', 'original_index'],
#       dtype='object')

# %%
x = train.groupby('ip').size()
print(x)
# Out:
# ip
# 6          1
# 16         1
# 36         1
# 52         1
# 62         1
# 81         1
# 85         2
# 87         1
# 88         2
# 92         3
# 93         5
# 104        2
# 114        2
# 120        2
# 122        5
# 124        1
# 128        1
# 133        3
# 134        1
# 143        2
# 150        3
# 151        1
# 165        4
# 169        3
# 175       36
# 176        2
# 184        1
# 188        1
# 195        1
# 198        6
#           ..
# 126171     8
# 126198     1
# 126200     4
# 126201     1
# 126202     1
# 126205     1
# 126209     2
# 126210     1
# 126217     1
# 126226     2
# 126229     1
# 126237     2
# 126242     2
# 126246     2
# 126249     2
# 126252     1
# 126275     1
# 126286     2
# 126292     1
# 126297     1
# 126302     1
# 126306     9
# 126308     1
# 126331    61
# 126335     8
# 126353     1
# 126362     2
# 126370     1
# 126401     2
# 126408     1
# Length: 17438, dtype: int64

# %%
print(train.loc[train['ip']==126331])
# Out:
#            ip  app  device  os  channel  day  hour   timestamp  minute  \
# 1640   126331   58       3  33      347   10     4  1510287250      14
# 1646   126331   58       3  33      347   10     4  1510287256      14
# 1662   126331   58       3  33      347   10     4  1510287261      14
# 1671   126331   58       3  33      347   10     4  1510287267      14
# 1679   126331   58       3  33      347   10     4  1510287272      14
# 1691   126331   58       3  33      347   10     4  1510287278      14
# 1706   126331   58       3  33      347   10     4  1510287283      14
# 1719   126331   58       3  33      347   10     4  1510287288      14
# 1734   126331   58       3  33      347   10     4  1510287295      14
# 1750   126331   58       3  33      347   10     4  1510287301      15
# 1762   126331   58       3  33      347   10     4  1510287307      15
# 1780   126331   58       3  33      347   10     4  1510287314      15
# ...
