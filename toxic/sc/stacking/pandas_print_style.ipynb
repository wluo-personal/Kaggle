# %%
import pandas as pd
import numpy as np

# %%
check = pd.read_csv('bad word check.csv')

# %%
pd.set_option('display.max_colwidth', 362)
pd.set_option('display.max_rows', 100)
#pd.set_option('display.width', 5)

# %%
check.iloc[:100]
# Out:
#                                                                                                                                                                                                                                                                                                                                                              comment_text_ori  \
# 0   You are gay or antisemmitian? \n\nArchangel WHite Tiger\n\nMeow! Greetingshhh!\n\nUh, there are two ways, why you do erased my comment about WW2, that holocaust was brutally slaying of Jews and not gays/Gypsys/Slavs/anyone...\n\n1 - If you are anti-semitian, than shave your head bald and go to the skinhead meetings!\n\n2 - If you doubt words of the Bible, ...
# ...

# %%
check.iloc[100:200]
# Out:
#                                                                                                                                                                                                                                                                                                                                                               comment_text_ori  \
# 100                                                                                                                                                                                                                                                                                                                                  You are achieving nothing you sockpuppet.
# ...

# %%
check.iloc[200:300]
# Out:
#                                                                                                                                                                                                                                                                                                                                                               comment_text_ori  \
# 200            {{unblock|Hello, I am writing this to request that you duly unblock my IP address from editing wikipedia.  Unfortunately, I am stuck in a class room full of imbeciles, preventing me from editing pages for the benefit of my fellow wikipedians.  Please, do not punish me for the cretinism of my peers and undue this great injustice.  Vive la resistance!
# ...

# %%
check.iloc[300:339]
# Out:
#                                                                                                                                                                                                                                                                                                                                                               comment_text_ori  \
# 300                                                                                                                                                                                          Conrad Devonshire \n\nHe's a proven sockpuppetter, I've added the link to the 'Sockpuppets of...' page, would have done it earlier but it took me half an hour to figure out how.
# ...

# %%
check.iloc[340:440]
# Out:
#                                                                                                                                                                                                                                                                                                                                                               comment_text_ori  \
# 340                                                                                                                                                                                                                                                                                                                                   Cluebot also says you have a tiny penis.
# ...

# %%
check.iloc[440:540]
# Out:
#                                                                                                                                                                                                                                                                                                                                                               comment_text_ori  \
# 440                                                                                                                                                                                                                                                                                                                Oh, and I am a sockpuppet of a guy called UNorginal, bitch!
# ...

# %%
check.iloc[540:640]
# Out:
#                                                                                                                                                                                                                                                                                                                                                               comment_text_ori  \
# 540                                                                                                                                                                                                                                                                                                                 hiding behind these bitches wikipedians who keep reverting
# ...

# %%
check.iloc[640:740]
# Out:
#                                                                                                                                                                                                                                                                                                                                                               comment_text_ori  \
# 640  "\n\nBitch, stop spreading your Mongol propaganda. Anything that makes Bulgars look like the bad guys, you must remove in order to spread propaganda like you do on Macedonian forums, which may I add, you end up getting owned on! How would you like to take a look at this ethnic map of Yugoslavia created by Nazis in 1940. Macedonians is included as a seperat...
# ...

# %%
check.iloc[740:840]
# Out:
#                                                                                                                                                                                                                                                                                                                                                               comment_text_ori  \
# 740                                        "::No, I won't unrevert your edits!""\n""sounds more like you're writing their MARKETING material!!""\n\nDon't get bossy with me. Or snippy either, Miss religious Bigot! \nKindly leave your hatred for Christianity at DailyKos before you log out there and log in over here as a...er...ahem...NPOV editor 99.185.56.156  \n\n"
# ...
