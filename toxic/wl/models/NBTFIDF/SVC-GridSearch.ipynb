# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import roc_auc_score
from scipy.sparse import csr_matrix, hstack

# %%
PATH = '../data/'

# train = pd.read_csv(PATH + 'cleaned_train_emoji.csv')
# test = pd.read_csv(PATH + 'cleaned_test_emoji.csv')

train = pd.read_csv(PATH + 'cleaned_train.csv')
test = pd.read_csv(PATH + 'cleaned_test.csv')


train_sentence = train['comment_text_cleaned_polarity']
test_sentence = test['comment_text_cleaned_polarity']


train_sentence_retain_punctuation = train['comment_text_cleaned_retain_punctuation']
test_sentence_retain_punctuation = test['comment_text_cleaned_retain_punctuation']

text = train_sentence

text_retain_punctuation = train_sentence_retain_punctuation


print(train.shape)
print(test.shape)
# Out:
# (159571, 30)
# (153164, 24)

# %%
phrase_vectorizer = TfidfVectorizer(ngram_range=(1,3),
                                    strip_accents='unicode', 
                                    max_features=100000, 
                                    analyzer='word',
                                    sublinear_tf=True,
                                    token_pattern=r'\w{1,}')
char_vectorizer = TfidfVectorizer(ngram_range=(2,5), 
                                  strip_accents='unicode', 
                                  max_features=200000, 
                                  analyzer='char', 
                                  sublinear_tf=True)

print('fitting char')
char_vectorizer.fit(text_retain_punctuation.values)
print('fitting phrase')
phrase_vectorizer.fit(text.values)

print('transforming train skip gram')

print('transforming train char')
train_char = char_vectorizer.transform(train_sentence_retain_punctuation.values)
print('transforming train phrase')
train_phrase = phrase_vectorizer.transform(train_sentence.values)


print('transforming test char')
test_char = char_vectorizer.transform(test_sentence_retain_punctuation.values)
print('transforming test phrase')
test_phrase = phrase_vectorizer.transform(test_sentence.values)


train_tfidf = hstack((train_char, train_phrase), format='csr')
test_tfidf = hstack((test_char, test_phrase), format='csr')

label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

train_tfidf
# Out:
# fitting char
# fitting phrase
# transforming train skip gram
# transforming train char
# transforming train phrase
# transforming test char
# transforming test phrase
# <159571x300000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 162813546 stored elements in Compressed Sparse Row format>

# %%
# from sklearn.model_selection import train_test_split
# x_train, x_val, y_train_df, y_val_df = train_test_split(train_tfidf, train, test_size=0.33)
# # Split the dataset



# Split the dataset
split_index = round(len(train) * 0.9) #################################
# shuffled_train = train#.sample(frac=1)
x_train = train_tfidf[:split_index]
y_train_df = train.iloc[:split_index]
#######
x_val = train_tfidf[split_index:]
y_val_df = train.iloc[split_index:]
# Get test data ready
x_test = test_tfidf


# train toxic
def pr(y_i, y, train_features):
    p = train_features[y==y_i].sum(0)
    return (p + 1) / ((y == y_i).sum() + 1)
r_dict = {label: np.log(pr(1, y_train_df[label].values, x_train) / pr(0,  y_train_df[label].values, x_train)) for label in label_cols}

# %%
train_set = {label: x_train.multiply(r_dict[label]).tocsr() for label in r_dict }
val_set = {label: x_val.multiply(r_dict[label]).tocsr() for label in r_dict }
test_set = {label: x_test.multiply(r_dict[label]).tocsr() for label in r_dict }

# del r_dict, x_train, x_val
import gc
gc.collect()
# Out:
# 278

# %%
import gc
gc.collect()
# Out:
# 0

# %%
cols = {'C': [], 'naive-bayes':[], 'label':[], 
        'precision':[], 'tpr':[], 'fpr':[], 
        'ROC':[],'trained':[]}
df_svc = pd.DataFrame(cols)
########################################

C = [0.01,0.02, 0.05,0.1,0.15,0.2,0.23,0.25,0.27,0.28,0.29,0.3,0.32,0.35,0.4,0.5,0.7,0.9,1,1.5,2,3,4,5,6,7,8]
NaiveB = ['Y', 'N']

index = 0
for col in label_cols:
    for cc in C:
        for nb in NaiveB:
            df_svc.loc[index, 'C'] = cc
            df_svc.loc[index, 'naive-bayes'] = nb
            df_svc.loc[index, 'label'] = col
            df_svc.loc[index, 'precision'] = 0
            df_svc.loc[index, 'tpr'] = 0
            df_svc.loc[index, 'fpr'] = 0
            df_svc.loc[index, 'ROC'] = 0
            df_svc.loc[index, 'trained'] = 'N'
            index += 1
                


df_svc.to_csv(PATH + 'svc_all_gridsearch_nonemoji.csv', index=False)

# %%
cols = {'C': [], 'naive-bayes':[], 'label':[], 
        'precision':[], 'tpr':[], 'fpr':[], 
        'ROC':[],'trained':[], 'fit_intercept': [], 'class_weight':[]}
df_svc = pd.DataFrame(cols)
########################################

C = [0.001,0.005,0.01,0.02,0.03, 0.05,0.1,0.15,0.2,0.23,0.25,0.27,0.28,0.29,0.3,0.32,0.35,0.4,0.5,0.7,0.9,1]
NaiveB = ['Y', 'N']
fit_intercept = ['False', 'True']
class_weight = ['None', 'balanced']

index = 0
for col in label_cols:
    for cc in C:
        for nb in NaiveB:
            for fi in fit_intercept:
                for cw in class_weight:
                    df_svc.loc[index, 'C'] = cc
                    df_svc.loc[index, 'naive-bayes'] = nb
                    df_svc.loc[index, 'label'] = col
                    df_svc.loc[index, 'precision'] = 0
                    df_svc.loc[index, 'tpr'] = 0
                    df_svc.loc[index, 'fpr'] = 0
                    df_svc.loc[index, 'ROC'] = 0
                    df_svc.loc[index, 'trained'] = 'N'
                    df_svc.loc[index, 'fit_intercept'] = fi
                    df_svc.loc[index, 'class_weight'] = cw
                    index += 1
                


df_svc.to_csv(PATH + 'svc_all_gridsearch_nonemoji_0306.csv', index=False)

# %%
def get_parameters(df_svc, addition = None):
    params_list =['C']
    condition = (df_svc['trained'] == 'N')
    if addition is not None:
        for i in range(len(addition)):
            condition = condition &  (df_svc[addition[i]['key']] == addition[i]['value'])
#     df = df_lgb[(df_lgb['trained'] == 'N') & (df_lgb['label'] == col)]
    df = df_svc[condition]
    index = df.index.values
    np.random.shuffle(index)
    next_index = index[0]
    params = dict(df_svc.loc[next_index, params_list])
    ##### data type fix:
    return params, next_index

# %%
def get_parameters(df_svc, addition = None):
    params_list =['C', 'fit_intercept', 'class_weight']
    condition = (df_svc['trained'] == 'N')
    if addition is not None:
        for i in range(len(addition)):
            condition = condition &  (df_svc[addition[i]['key']] == addition[i]['value'])
#     df = df_lgb[(df_lgb['trained'] == 'N') & (df_lgb['label'] == col)]
    df = df_svc[condition]
    index = df.index.values
    np.random.shuffle(index)
    next_index = index[0]
    params = dict(df_svc.loc[next_index, params_list])
    ########
    params['fit_intercept'] = bool( params['fit_intercept'])
    if params['class_weight'] is 'balanced':
        params['class_weight'] = 'balanced'
    else:
        params['class_weight'] = None
    ##### data type fix:
    return params, next_index

# %%
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import roc_auc_score, confusion_matrix

################# random search start
# %env JOBLIB_TEMP_FOLDER=/tmp
base_params = {}
start = 0
for i in range(1000):
        start += 1
        # create dataset for lightgbm
        params = base_params.copy()  
        params_get, index_get = get_parameters(df_svc, addition=None)
        col = df_svc.loc[index_get, 'label']
        y_val = y_val_df[col].values
        y_train = y_train_df[col].values
        ###### check naive bayes
        nb = df_svc.loc[index_get, 'naive-bayes']
        if nb is 'Y':
            svc_train = x_train
            svc_val = x_val
            print('nb enabled')
        else:
            svc_train = train_set[col]
            svc_val = val_set[col]
            print('nb disabled')
        params.update(params_get)
        print(start)
        print(col)
        print(index_get)
        print(params)
        lsvc = LinearSVC(**params_get)
        model_svc = CalibratedClassifierCV(lsvc) 
        model_svc.fit(svc_train, y_train)
        pred_prob = model_svc.predict_proba(svc_val)[:,1]
        pred = model_svc.predict(svc_val)
        roc = roc_auc_score(y_val,pred_prob)
        tn, fp, fn, tp = confusion_matrix(y_val, pred).ravel()
        precision = tp / (tp + fp)
        tpr = tp / (tp + fn)
        fpr = fp / (fp + tn)

        df_svc.loc[index_get, 'precision'] = precision
        df_svc.loc[index_get, 'tpr'] = tpr
        df_svc.loc[index_get, 'fpr'] = fpr
        df_svc.loc[index_get, 'ROC'] = roc
        df_svc.loc[index_get, 'trained'] = 'Y'
        print(df_svc.iloc[index_get])
        i += 1
        print('==================================================')
        df_svc.to_csv(PATH + 'svc_all_gridsearch_nonemoji_0306.csv', index=False) 
        print('done')
        print('===================================')
# Out:
# env: JOBLIB_TEMP_FOLDER=/tmp
# nb enabled
# 1
# obscene
# 464
# {'C': 0.29999999999999999, 'fit_intercept': True, 'class_weight': None}
# C                       0.3
# ROC                 0.99145
# class_weight           None
# fit_intercept         False
# fpr              0.00602929
# label               obscene
# naive-bayes               Y
# precision          0.877852
# tpr                0.756944
# trained                   Y
# Name: 464, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 2
# insult
# 740
# {'C': 0.029999999999999999, 'fit_intercept': True, 'class_weight': None}
# C                      0.03
# ROC                0.984801
# class_weight           None
# fit_intercept         False
# fpr              0.00733157
# label                insult
# naive-bayes               N
# precision           0.81592
# tpr                0.602203
# trained                   Y
# Name: 740, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 3
# insult
# 715
# {'C': 0.0050000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                     0.005
# ROC                  0.9773
# class_weight       balanced
# fit_intercept          True
# fpr              0.00785997
# label                insult
# naive-bayes               Y
# precision          0.794118
# tpr                0.561812
# trained                   Y
# Name: 715, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 4
# insult
# 869
# {'C': 0.90000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.9
# ROC                0.979801
# class_weight       balanced
# fit_intercept         False
# fpr              0.00746367
# label                insult
# naive-bayes               N
# precision          0.807167
# tpr                0.578947
# trained                   Y
# Name: 869, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 5
# threat
# 632
# {'C': 0.28999999999999998, 'fit_intercept': True, 'class_weight': None}
# C                       0.29
# ROC                 0.992552
# class_weight            None
# fit_intercept          False
# fpr              0.000565789
# label                 threat
# naive-bayes                Y
# precision           0.666667
# tpr                     0.36
# trained                    Y
# Name: 632, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 6
# obscene
# 392
# {'C': 0.050000000000000003, 'fit_intercept': True, 'class_weight': None}
# C                      0.05
# ROC                0.991676
# class_weight           None
# fit_intercept         False
# fpr              0.00602929
# label               obscene
# naive-bayes               Y
# precision          0.876526
# tpr                0.747685
# trained                   Y
# Name: 392, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 7
# severe_toxic
# 244
# {'C': 0.20000000000000001, 'fit_intercept': True, 'class_weight': None}
# C                         0.2
# ROC                  0.987627
# class_weight             None
# fit_intercept           False
# fpr                0.00183463
# label            severe_toxic
# naive-bayes                 N
# precision            0.585714
# tpr                  0.273333
# trained                     Y
# Name: 244, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 8
# insult
# 773
# {'C': 0.20000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.2
# ROC                0.983203
# class_weight       balanced
# fit_intercept         False
# fpr              0.00832232
# label                insult
# naive-bayes               N
# precision            0.7984
# tpr                0.610771
# trained                   Y
# Name: 773, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 9
# insult
# 809
# {'C': 0.28999999999999998, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.29
# ROC                0.982165
# class_weight       balanced
# fit_intercept         False
# fpr              0.00819022
# label                insult
# naive-bayes               Y
# precision            0.8016
# tpr                0.613219
# trained                   Y
# Name: 809, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 10
# toxic
# 117
# {'C': 0.29999999999999999, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.3
# ROC                0.984001
# class_weight       balanced
# fit_intercept         False
# fpr              0.00985153
# label                 toxic
# naive-bayes               N
# precision          0.888189
# tpr                0.731043
# trained                   Y
# Name: 117, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 11
# severe_toxic
# 309
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.35
# ROC                  0.987131
# class_weight         balanced
# fit_intercept           False
# fpr                0.00196116
# label            severe_toxic
# naive-bayes                 N
# precision            0.544118
# tpr                  0.246667
# trained                     Y
# Name: 309, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 12
# obscene
# 491
# {'C': 0.40000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.4
# ROC                0.991179
# class_weight       balanced
# fit_intercept          True
# fpr              0.00662559
# label               obscene
# naive-bayes               Y
# precision          0.865952
# tpr                0.747685
# trained                   Y
# Name: 491, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 13
# toxic
# 139
# {'C': 0.40000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.4
# ROC               0.981766
# class_weight      balanced
# fit_intercept         True
# fpr              0.0096434
# label                toxic
# naive-bayes              Y
# precision           0.8888
# tpr               0.720026
# trained                  Y
# Name: 139, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 14
# toxic
# 140
# {'C': 0.40000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                       0.4
# ROC                0.983795
# class_weight           None
# fit_intercept         False
# fpr              0.00936589
# label                 toxic
# naive-bayes               N
# precision          0.892942
# tpr                0.729747
# trained                   Y
# Name: 140, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 15
# identity_hate
# 981
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                         0.28
# ROC                   0.985707
# class_weight          balanced
# fit_intercept            False
# fpr                 0.00164422
# label            identity_hate
# naive-bayes                  N
# precision             0.638889
# tpr                   0.319444
# trained                      Y
# Name: 981, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 16
# identity_hate
# 937
# {'C': 0.14999999999999999, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                         0.15
# ROC                   0.987372
# class_weight          balanced
# fit_intercept            False
# fpr                 0.00164422
# label            identity_hate
# naive-bayes                  Y
# precision             0.638889
# tpr                   0.319444
# trained                      Y
# Name: 937, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 17
# threat
# 701
# {'C': 1.0, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                          1
# ROC                 0.987035
# class_weight        balanced
# fit_intercept          False
# fpr              0.000440058
# label                 threat
# naive-bayes                N
# precision           0.730769
# tpr                     0.38
# trained                    Y
# Name: 701, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 18
# identity_hate
# 931
# {'C': 0.10000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                          0.1
# ROC                   0.987656
# class_weight          balanced
# fit_intercept             True
# fpr                 0.00164422
# label            identity_hate
# naive-bayes                  Y
# precision             0.638889
# tpr                   0.319444
# trained                      Y
# Name: 931, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 19
# severe_toxic
# 339
# {'C': 0.90000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                         0.9
# ROC                  0.984072
# class_weight         balanced
# fit_intercept            True
# fpr                0.00234074
# label            severe_toxic
# naive-bayes                 Y
# precision            0.513158
# tpr                      0.26
# trained                     Y
# Name: 339, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 20
# insult
# 840
# {'C': 0.40000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                       0.4
# ROC                0.980109
# class_weight           None
# fit_intercept         False
# fpr              0.00779392
# label                insult
# naive-bayes               Y
# precision          0.806557
# tpr                0.602203
# trained                   Y
# Name: 840, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 21
# obscene
# 430
# {'C': 0.23000000000000001, 'fit_intercept': True, 'class_weight': None}
# C                      0.23
# ROC                0.992602
# class_weight           None
# fit_intercept          True
# fpr              0.00563175
# label               obscene
# naive-bayes               N
# precision          0.882434
# tpr                0.738426
# trained                   Y
# Name: 430, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 22
# threat
# 546
# {'C': 0.01, 'fit_intercept': True, 'class_weight': None}
# C                       0.01
# ROC                 0.989136
# class_weight            None
# fit_intercept           True
# fpr              0.000691519
# label                 threat
# naive-bayes                Y
# precision               0.56
# tpr                     0.28
# trained                    Y
# Name: 546, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 23
# severe_toxic
# 218
# {'C': 0.050000000000000003, 'fit_intercept': True, 'class_weight': None}
# C                        0.05
# ROC                  0.989142
# class_weight             None
# fit_intercept            True
# fpr                0.00278358
# label            severe_toxic
# naive-bayes                 Y
# precision            0.488372
# tpr                      0.28
# trained                     Y
# Name: 218, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 24
# obscene
# 481
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.35
# ROC                 0.99131
# class_weight       balanced
# fit_intercept         False
# fpr              0.00662559
# label               obscene
# naive-bayes               Y
# precision           0.86631
# tpr                    0.75
# trained                   Y
# Name: 481, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 25
# identity_hate
# 1049
# {'C': 1.0, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                            1
# ROC                    0.98393
# class_weight          balanced
# fit_intercept            False
# fpr                 0.00151774
# label            identity_hate
# naive-bayes                  Y
# precision             0.641791
# tpr                   0.298611
# trained                      Y
# Name: 1049, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 26
# obscene
# 502
# {'C': 0.5, 'fit_intercept': True, 'class_weight': None}
# C                       0.5
# ROC                0.991812
# class_weight           None
# fit_intercept          True
# fpr              0.00589677
# label               obscene
# naive-bayes               N
# precision          0.876389
# tpr                0.730324
# trained                   Y
# Name: 502, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 27
# identity_hate
# 945
# {'C': 0.20000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                          0.2
# ROC                   0.987088
# class_weight          balanced
# fit_intercept            False
# fpr                 0.00151774
# label            identity_hate
# naive-bayes                  Y
# precision             0.661972
# tpr                   0.326389
# trained                      Y
# Name: 945, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 28
# threat
# 658
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': None}
# C                       0.35
# ROC                 0.992252
# class_weight            None
# fit_intercept           True
# fpr              0.000565789
# label                 threat
# naive-bayes                Y
# precision           0.666667
# tpr                     0.36
# trained                    Y
# Name: 658, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 29
# insult
# 825
# {'C': 0.32000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.32
# ROC                0.981956
# class_weight       balanced
# fit_intercept         False
# fpr              0.00819022
# label                insult
# naive-bayes               Y
# precision          0.800963
# tpr                0.610771
# trained                   Y
# Name: 825, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 30
# insult
# 866
# {'C': 0.90000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                       0.9
# ROC                0.977862
# class_weight           None
# fit_intercept          True
# fpr              0.00739762
# label                insult
# naive-bayes               Y
# precision          0.811448
# tpr                0.589963
# trained                   Y
# Name: 866, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 31
# threat
# 660
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': None}
# C                       0.35
# ROC                 0.989498
# class_weight            None
# fit_intercept          False
# fpr              0.000440058
# label                 threat
# naive-bayes                N
# precision           0.730769
# tpr                     0.38
# trained                    Y
# Name: 660, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 32
# toxic
# 146
# {'C': 0.5, 'fit_intercept': True, 'class_weight': None}
# C                       0.5
# ROC                 0.98188
# class_weight           None
# fit_intercept          True
# fpr              0.00915776
# label                 toxic
# naive-bayes               Y
# precision          0.894231
# tpr                0.723266
# trained                   Y
# Name: 146, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 33
# threat
# 663
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.35
# ROC                 0.988773
# class_weight        balanced
# fit_intercept           True
# fpr              0.000440058
# label                 threat
# naive-bayes                N
# precision           0.730769
# tpr                     0.38
# trained                    Y
# Name: 663, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 34
# toxic
# 147
# {'C': 0.5, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.5
# ROC                0.981497
# class_weight       balanced
# fit_intercept          True
# fpr              0.00922714
# label                 toxic
# naive-bayes               Y
# precision          0.892828
# tpr                0.718082
# trained                   Y
# Name: 147, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 35
# identity_hate
# 1045
# {'C': 0.90000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                          0.9
# ROC                   0.983939
# class_weight          balanced
# fit_intercept            False
# fpr                 0.00151774
# label            identity_hate
# naive-bayes                  N
# precision             0.647059
# tpr                   0.305556
# trained                      Y
# Name: 1045, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 36
# identity_hate
# 949
# {'C': 0.20000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                          0.2
# ROC                    0.98626
# class_weight          balanced
# fit_intercept            False
# fpr                 0.00158098
# label            identity_hate
# naive-bayes                  N
# precision             0.647887
# tpr                   0.319444
# trained                      Y
# Name: 949, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 37
# identity_hate
# 1040
# {'C': 0.90000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                          0.9
# ROC                     0.9827
# class_weight              None
# fit_intercept            False
# fpr                 0.00132802
# label            identity_hate
# naive-bayes                  Y
# precision             0.691176
# tpr                   0.326389
# trained                      Y
# Name: 1040, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 38
# insult
# 834
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': None}
# C                      0.35
# ROC                0.980449
# class_weight           None
# fit_intercept          True
# fpr              0.00792602
# label                insult
# naive-bayes               Y
# precision          0.803601
# tpr                0.600979
# trained                   Y
# Name: 834, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 39
# insult
# 762
# {'C': 0.14999999999999999, 'fit_intercept': True, 'class_weight': None}
# C                      0.15
# ROC                0.982175
# class_weight           None
# fit_intercept          True
# fpr              0.00746367
# label                insult
# naive-bayes               Y
# precision          0.813839
# tpr                0.604651
# trained                   Y
# Name: 762, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 40
# toxic
# 145
# {'C': 0.5, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.5
# ROC                0.981497
# class_weight       balanced
# fit_intercept         False
# fpr              0.00922714
# label                 toxic
# naive-bayes               Y
# precision          0.892828
# tpr                0.718082
# trained                   Y
# Name: 145, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 41
# threat
# 615
# {'C': 0.25, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.25
# ROC                 0.989191
# class_weight        balanced
# fit_intercept           True
# fpr              0.000502923
# label                 threat
# naive-bayes                N
# precision           0.692308
# tpr                     0.36
# trained                    Y
# Name: 615, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 42
# severe_toxic
# 278
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': None}
# C                        0.28
# ROC                  0.987174
# class_weight             None
# fit_intercept            True
# fpr                0.00189789
# label            severe_toxic
# naive-bayes                 N
# precision            0.565217
# tpr                      0.26
# trained                     Y
# Name: 278, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 43
# toxic
# 25
# {'C': 0.02, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                     0.02
# ROC               0.978245
# class_weight      balanced
# fit_intercept        False
# fpr              0.0111003
# label                toxic
# naive-bayes              Y
# precision         0.872306
# tpr                0.70836
# trained                  Y
# Name: 25, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 44
# severe_toxic
# 338
# {'C': 0.90000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                         0.9
# ROC                  0.983237
# class_weight             None
# fit_intercept            True
# fpr                0.00215095
# label            severe_toxic
# naive-bayes                 Y
# precision            0.534247
# tpr                      0.26
# trained                     Y
# Name: 338, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 45
# severe_toxic
# 279
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.28
# ROC                  0.987433
# class_weight         balanced
# fit_intercept            True
# fpr                0.00202442
# label            severe_toxic
# naive-bayes                 N
# precision            0.542857
# tpr                  0.253333
# trained                     Y
# Name: 279, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 46
# severe_toxic
# 250
# {'C': 0.23000000000000001, 'fit_intercept': True, 'class_weight': None}
# C                        0.23
# ROC                  0.987372
# class_weight             None
# fit_intercept            True
# fpr                0.00265705
# label            severe_toxic
# naive-bayes                 Y
# precision                 0.5
# tpr                      0.28
# trained                     Y
# Name: 250, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 47
# threat
# 545
# {'C': 0.01, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.01
# ROC                 0.991537
# class_weight        balanced
# fit_intercept          False
# fpr              0.000691519
# label                 threat
# naive-bayes                Y
# precision           0.576923
# tpr                      0.3
# trained                    Y
# Name: 545, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 48
# severe_toxic
# 232
# {'C': 0.14999999999999999, 'fit_intercept': True, 'class_weight': None}
# C                        0.15
# ROC                  0.988328
# class_weight             None
# fit_intercept           False
# fpr                0.00278358
# label            severe_toxic
# naive-bayes                 Y
# precision            0.488372
# tpr                      0.28
# trained                     Y
# Name: 232, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 49
# obscene
# 437
# {'C': 0.25, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.25
# ROC                0.992596
# class_weight       balanced
# fit_intercept         False
# fpr              0.00649308
# label               obscene
# naive-bayes               N
# precision          0.867209
# tpr                0.740741
# trained                   Y
# Name: 437, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 50
# toxic
# 105
# {'C': 0.28999999999999998, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.29
# ROC                 0.98206
# class_weight       balanced
# fit_intercept         False
# fpr              0.00971278
# label                 toxic
# naive-bayes               Y
# precision          0.888535
# tpr                0.723266
# trained                   Y
# Name: 105, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 51
# identity_hate
# 1029
# {'C': 0.5, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                          0.5
# ROC                   0.984775
# class_weight          balanced
# fit_intercept            False
# fpr                 0.00158098
# label            identity_hate
# naive-bayes                  N
# precision             0.642857
# tpr                     0.3125
# trained                      Y
# Name: 1029, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 52
# insult
# 804
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': None}
# C                      0.28
# ROC                0.981622
# class_weight           None
# fit_intercept         False
# fpr              0.00733157
# label                insult
# naive-bayes               N
# precision          0.813758
# tpr                0.593635
# trained                   Y
# Name: 804, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 53
# severe_toxic
# 340
# {'C': 0.90000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                         0.9
# ROC                  0.985773
# class_weight             None
# fit_intercept           False
# fpr                 0.0017081
# label            severe_toxic
# naive-bayes                 N
# precision            0.534483
# tpr                  0.206667
# trained                     Y
# Name: 340, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 54
# identity_hate
# 998
# {'C': 0.29999999999999999, 'fit_intercept': True, 'class_weight': None}
# C                          0.3
# ROC                   0.984852
# class_weight              None
# fit_intercept             True
# fpr                 0.00132802
# label            identity_hate
# naive-bayes                  N
# precision             0.676923
# tpr                   0.305556
# trained                      Y
# Name: 998, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 55
# severe_toxic
# 181
# {'C': 0.001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.001
# ROC                  0.988705
# class_weight         balanced
# fit_intercept           False
# fpr                0.00272031
# label            severe_toxic
# naive-bayes                 N
# precision            0.448718
# tpr                  0.233333
# trained                     Y
# Name: 181, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 56
# identity_hate
# 921
# {'C': 0.050000000000000003, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                         0.05
# ROC                   0.987719
# class_weight          balanced
# fit_intercept            False
# fpr                  0.0014545
# label            identity_hate
# naive-bayes                  Y
# precision             0.646154
# tpr                   0.291667
# trained                      Y
# Name: 921, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 57
# threat
# 683
# {'C': 0.69999999999999996, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.7
# ROC                 0.990619
# class_weight        balanced
# fit_intercept           True
# fpr              0.000502923
# label                 threat
# naive-bayes                Y
# precision           0.692308
# tpr                     0.36
# trained                    Y
# Name: 683, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 58
# threat
# 635
# {'C': 0.28999999999999998, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.29
# ROC                 0.991963
# class_weight        balanced
# fit_intercept           True
# fpr              0.000502923
# label                 threat
# naive-bayes                Y
# precision           0.692308
# tpr                     0.36
# trained                    Y
# Name: 635, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 59
# threat
# 593
# {'C': 0.20000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.2
# ROC                 0.992334
# class_weight        balanced
# fit_intercept          False
# fpr              0.000628654
# label                 threat
# naive-bayes                Y
# precision           0.615385
# tpr                     0.32
# trained                    Y
# Name: 593, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 60
# identity_hate
# 920
# {'C': 0.050000000000000003, 'fit_intercept': True, 'class_weight': None}
# C                         0.05
# ROC                   0.986172
# class_weight              None
# fit_intercept            False
# fpr                 0.00158098
# label            identity_hate
# naive-bayes                  Y
# precision             0.652778
# tpr                   0.326389
# trained                      Y
# Name: 920, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 61
# threat
# 591
# {'C': 0.14999999999999999, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.15
# ROC                 0.989848
# class_weight        balanced
# fit_intercept           True
# fpr              0.000502923
# label                 threat
# naive-bayes                N
# precision           0.692308
# tpr                     0.36
# trained                    Y
# Name: 591, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 62
# threat
# 665
# {'C': 0.40000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.4
# ROC                 0.991558
# class_weight        balanced
# fit_intercept          False
# fpr              0.000502923
# label                 threat
# naive-bayes                Y
# precision           0.692308
# tpr                     0.36
# trained                    Y
# Name: 665, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 63
# identity_hate
# 1016
# {'C': 0.40000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                          0.4
# ROC                   0.984594
# class_weight              None
# fit_intercept            False
# fpr                 0.00151774
# label            identity_hate
# naive-bayes                  Y
# precision             0.661972
# tpr                   0.326389
# trained                      Y
# Name: 1016, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 64
# obscene
# 380
# {'C': 0.02, 'fit_intercept': True, 'class_weight': None}
# C                      0.02
# ROC                0.993031
# class_weight           None
# fit_intercept         False
# fpr              0.00536673
# label               obscene
# naive-bayes               N
# precision          0.886555
# tpr                0.732639
# trained                   Y
# Name: 380, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 65
# toxic
# 59
# {'C': 0.14999999999999999, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                     0.15
# ROC               0.982313
# class_weight      balanced
# fit_intercept         True
# fpr              0.0104065
# label                toxic
# naive-bayes              Y
# precision         0.882261
# tpr               0.728451
# trained                  Y
# Name: 59, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 66
# threat
# 679
# {'C': 0.5, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.5
# ROC                 0.988298
# class_weight        balanced
# fit_intercept           True
# fpr              0.000440058
# label                 threat
# naive-bayes                N
# precision           0.730769
# tpr                     0.38
# trained                    Y
# Name: 679, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 67
# severe_toxic
# 196
# {'C': 0.01, 'fit_intercept': True, 'class_weight': None}
# C                        0.01
# ROC                  0.989741
# class_weight             None
# fit_intercept           False
# fpr                0.00246726
# label            severe_toxic
# naive-bayes                 N
# precision                 0.5
# tpr                      0.26
# trained                     Y
# Name: 196, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 68
# severe_toxic
# 182
# {'C': 0.001, 'fit_intercept': True, 'class_weight': None}
# C                       0.001
# ROC                  0.987501
# class_weight             None
# fit_intercept            True
# fpr                  0.002404
# label            severe_toxic
# naive-bayes                 N
# precision            0.512821
# tpr                  0.266667
# trained                     Y
# Name: 182, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 69
# threat
# 627
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.28
# ROC                 0.991993
# class_weight        balanced
# fit_intercept           True
# fpr              0.000502923
# label                 threat
# naive-bayes                Y
# precision           0.692308
# tpr                     0.36
# trained                    Y
# Name: 627, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 70
# insult
# 802
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': None}
# C                      0.28
# ROC                0.980975
# class_weight           None
# fit_intercept          True
# fpr              0.00759577
# label                insult
# naive-bayes               Y
# precision          0.810855
# tpr                0.603427
# trained                   Y
# Name: 802, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 71
# identity_hate
# 907
# {'C': 0.02, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                         0.02
# ROC                   0.987084
# class_weight          balanced
# fit_intercept             True
# fpr                 0.00177069
# label            identity_hate
# naive-bayes                  Y
# precision             0.588235
# tpr                   0.277778
# trained                      Y
# Name: 907, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 72
# toxic
# 58
# {'C': 0.14999999999999999, 'fit_intercept': True, 'class_weight': None}
# C                      0.15
# ROC                0.983134
# class_weight           None
# fit_intercept          True
# fpr              0.00957403
# label                 toxic
# naive-bayes               Y
# precision          0.891934
# tpr                0.738172
# trained                   Y
# Name: 58, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 73
# severe_toxic
# 221
# {'C': 0.050000000000000003, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.05
# ROC                  0.989232
# class_weight         balanced
# fit_intercept           False
# fpr                  0.002404
# label            severe_toxic
# naive-bayes                 N
# precision            0.512821
# tpr                  0.266667
# trained                     Y
# Name: 221, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 74
# insult
# 863
# {'C': 0.69999999999999996, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.7
# ROC                0.980461
# class_weight       balanced
# fit_intercept          True
# fpr              0.00746367
# label                insult
# naive-bayes               N
# precision          0.809764
# tpr                0.588739
# trained                   Y
# Name: 863, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 75
# threat
# 576
# {'C': 0.10000000000000001, 'fit_intercept': True, 'class_weight': None}
# C                        0.1
# ROC                 0.993317
# class_weight            None
# fit_intercept          False
# fpr              0.000565789
# label                 threat
# naive-bayes                Y
# precision               0.64
# tpr                     0.32
# trained                    Y
# Name: 576, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 76
# obscene
# 467
# {'C': 0.29999999999999999, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.3
# ROC               0.991431
# class_weight      balanced
# fit_intercept         True
# fpr              0.0067581
# label              obscene
# naive-bayes              Y
# precision            0.864
# tpr                   0.75
# trained                  Y
# Name: 467, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 77
# insult
# 705
# {'C': 0.001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                     0.001
# ROC                0.965324
# class_weight       balanced
# fit_intercept         False
# fpr              0.00766182
# label                insult
# naive-bayes               Y
# precision          0.778203
# tpr                0.498164
# trained                   Y
# Name: 705, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 78
# insult
# 837
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.35
# ROC                0.982106
# class_weight       balanced
# fit_intercept         False
# fpr              0.00792602
# label                insult
# naive-bayes               N
# precision           0.80456
# tpr                0.604651
# trained                   Y
# Name: 837, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 79
# threat
# 628
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': None}
# C                       0.28
# ROC                 0.989835
# class_weight            None
# fit_intercept          False
# fpr              0.000440058
# label                 threat
# naive-bayes                N
# precision           0.730769
# tpr                     0.38
# trained                    Y
# Name: 628, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 80
# severe_toxic
# 267
# {'C': 0.27000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.27
# ROC                  0.987506
# class_weight         balanced
# fit_intercept            True
# fpr                0.00272031
# label            severe_toxic
# naive-bayes                 Y
# precision             0.47561
# tpr                      0.26
# trained                     Y
# Name: 267, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 81
# threat
# 558
# {'C': 0.02, 'fit_intercept': True, 'class_weight': None}
# C                       0.02
# ROC                 0.993134
# class_weight            None
# fit_intercept           True
# fpr              0.000502923
# label                 threat
# naive-bayes                N
# precision           0.692308
# tpr                     0.36
# trained                    Y
# Name: 558, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 82
# identity_hate
# 910
# {'C': 0.02, 'fit_intercept': True, 'class_weight': None}
# C                         0.02
# ROC                   0.988143
# class_weight              None
# fit_intercept             True
# fpr                  0.0014545
# label            identity_hate
# naive-bayes                  N
# precision             0.671429
# tpr                   0.326389
# trained                      Y
# Name: 910, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 83
# severe_toxic
# 294
# {'C': 0.29999999999999999, 'fit_intercept': True, 'class_weight': None}
# C                         0.3
# ROC                  0.987075
# class_weight             None
# fit_intercept            True
# fpr                0.00189789
# label            severe_toxic
# naive-bayes                 N
# precision            0.558824
# tpr                  0.253333
# trained                     Y
# Name: 294, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 84
# severe_toxic
# 249
# {'C': 0.23000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.23
# ROC                  0.987847
# class_weight         balanced
# fit_intercept           False
# fpr                0.00278358
# label            severe_toxic
# naive-bayes                 Y
# precision            0.482353
# tpr                  0.273333
# trained                     Y
# Name: 249, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 85
# insult
# 769
# {'C': 0.20000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.2
# ROC                0.982822
# class_weight       balanced
# fit_intercept         False
# fpr              0.00819022
# label                insult
# naive-bayes               Y
# precision          0.801917
# tpr                0.614443
# trained                   Y
# Name: 769, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 86
# insult
# 799
# {'C': 0.27000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.27
# ROC                0.982653
# class_weight       balanced
# fit_intercept          True
# fpr              0.00819022
# label                insult
# naive-bayes               N
# precision          0.799353
# tpr                0.604651
# trained                   Y
# Name: 799, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 87
# threat
# 534
# {'C': 0.001, 'fit_intercept': True, 'class_weight': None}
# C                      0.001
# ROC                 0.990383
# class_weight            None
# fit_intercept           True
# fpr              0.000502923
# label                 threat
# naive-bayes                N
# precision           0.619048
# tpr                     0.26
# trained                    Y
# Name: 534, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 88
# obscene
# 482
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': None}
# C                      0.35
# ROC                0.991264
# class_weight           None
# fit_intercept          True
# fpr              0.00609554
# label               obscene
# naive-bayes               Y
# precision          0.876344
# tpr                 0.75463
# trained                   Y
# Name: 482, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 89
# obscene
# 366
# {'C': 0.0050000000000000001, 'fit_intercept': True, 'class_weight': None}
# C                     0.005
# ROC                0.992101
# class_weight           None
# fit_intercept          True
# fpr              0.00483668
# label               obscene
# naive-bayes               N
# precision          0.895265
# tpr                0.722222
# trained                   Y
# Name: 366, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 90
# toxic
# 63
# {'C': 0.14999999999999999, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.15
# ROC                 0.98466
# class_weight       balanced
# fit_intercept          True
# fpr              0.00992091
# label                 toxic
# naive-bayes               N
# precision          0.888456
# tpr                0.738172
# trained                   Y
# Name: 63, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 91
# toxic
# 88
# {'C': 0.27000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                      0.27
# ROC                0.982759
# class_weight           None
# fit_intercept         False
# fpr              0.00915776
# label                 toxic
# naive-bayes               Y
# precision           0.89557
# tpr                0.733636
# trained                   Y
# Name: 88, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 92
# insult
# 868
# {'C': 0.90000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                       0.9
# ROC                0.978477
# class_weight           None
# fit_intercept         False
# fpr              0.00713342
# label                insult
# naive-bayes               N
# precision          0.811189
# tpr                0.567931
# trained                   Y
# Name: 868, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 93
# identity_hate
# 977
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                         0.28
# ROC                   0.986683
# class_weight          balanced
# fit_intercept            False
# fpr                  0.0014545
# label            identity_hate
# naive-bayes                  Y
# precision             0.671429
# tpr                   0.326389
# trained                      Y
# Name: 977, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 94
# toxic
# 7
# {'C': 0.001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                    0.001
# ROC               0.975802
# class_weight      balanced
# fit_intercept         True
# fpr              0.0105453
# label                toxic
# naive-bayes              N
# precision            0.875
# tpr               0.689566
# trained                  Y
# Name: 7, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 95
# toxic
# 116
# {'C': 0.29999999999999999, 'fit_intercept': True, 'class_weight': None}
# C                       0.3
# ROC                0.984172
# class_weight           None
# fit_intercept         False
# fpr              0.00929652
# label                 toxic
# naive-bayes               N
# precision          0.894155
# tpr                0.733636
# trained                   Y
# Name: 116, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 96
# identity_hate
# 943
# {'C': 0.14999999999999999, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                         0.15
# ROC                   0.986738
# class_weight          balanced
# fit_intercept             True
# fpr                 0.00151774
# label            identity_hate
# naive-bayes                  N
# precision             0.666667
# tpr                   0.333333
# trained                      Y
# Name: 943, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 97
# threat
# 547
# {'C': 0.01, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.01
# ROC                 0.991537
# class_weight        balanced
# fit_intercept           True
# fpr              0.000691519
# label                 threat
# naive-bayes                Y
# precision           0.576923
# tpr                      0.3
# trained                    Y
# Name: 547, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 98
# severe_toxic
# 273
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.28
# ROC                  0.987421
# class_weight         balanced
# fit_intercept           False
# fpr                0.00272031
# label            severe_toxic
# naive-bayes                 Y
# precision             0.47561
# tpr                      0.26
# trained                     Y
# Name: 273, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 99
# toxic
# 14
# {'C': 0.0050000000000000001, 'fit_intercept': True, 'class_weight': None}
# C                    0.005
# ROC               0.979502
# class_weight          None
# fit_intercept         True
# fpr              0.0101984
# label                toxic
# naive-bayes              N
# precision         0.880391
# tpr               0.701231
# trained                  Y
# Name: 14, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 100
# severe_toxic
# 275
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.28
# ROC                  0.987421
# class_weight         balanced
# fit_intercept            True
# fpr                0.00272031
# label            severe_toxic
# naive-bayes                 Y
# precision             0.47561
# tpr                      0.26
# trained                     Y
# Name: 275, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 101
# toxic
# 17
# {'C': 0.01, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                     0.01
# ROC               0.974189
# class_weight      balanced
# fit_intercept        False
# fpr              0.0123491
# label                toxic
# naive-bayes              Y
# precision         0.857143
# tpr               0.692158
# trained                  Y
# Name: 17, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 102
# obscene
# 478
# {'C': 0.32000000000000001, 'fit_intercept': True, 'class_weight': None}
# C                      0.32
# ROC                0.992287
# class_weight           None
# fit_intercept          True
# fpr              0.00563175
# label               obscene
# naive-bayes               N
# precision          0.882271
# tpr                0.737269
# trained                   Y
# Name: 478, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 103
# toxic
# 22
# {'C': 0.01, 'fit_intercept': True, 'class_weight': None}
# C                     0.01
# ROC               0.981391
# class_weight          None
# fit_intercept         True
# fpr              0.0100597
# label                toxic
# naive-bayes              N
# precision          0.88437
# tpr                0.71873
# trained                  Y
# Name: 22, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 104
# identity_hate
# 976
# {'C': 0.28000000000000003, 'fit_intercept': True, 'class_weight': None}
# C                         0.28
# ROC                   0.985249
# class_weight              None
# fit_intercept            False
# fpr                 0.00151774
# label            identity_hate
# naive-bayes                  Y
# precision             0.675676
# tpr                   0.347222
# trained                      Y
# Name: 976, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 105
# threat
# 543
# {'C': 0.0050000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.005
# ROC                 0.994221
# class_weight        balanced
# fit_intercept           True
# fpr              0.000691519
# label                 threat
# naive-bayes                N
# precision           0.592593
# tpr                     0.32
# trained                    Y
# Name: 543, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 106
# toxic
# 141
# {'C': 0.40000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.4
# ROC               0.983633
# class_weight      balanced
# fit_intercept        False
# fpr              0.0100597
# label                toxic
# naive-bayes              N
# precision         0.885827
# tpr               0.729099
# trained                  Y
# Name: 141, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 107
# threat
# 645
# {'C': 0.29999999999999999, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                        0.3
# ROC                 0.988976
# class_weight        balanced
# fit_intercept          False
# fpr              0.000502923
# label                 threat
# naive-bayes                N
# precision           0.703704
# tpr                     0.38
# trained                    Y
# Name: 645, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 108
# insult
# 785
# {'C': 0.25, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.25
# ROC                0.982458
# class_weight       balanced
# fit_intercept         False
# fpr              0.00812417
# label                insult
# naive-bayes               Y
# precision          0.801932
# tpr                0.609547
# trained                   Y
# Name: 785, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 109
# toxic
# 19
# {'C': 0.01, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                     0.01
# ROC               0.974189
# class_weight      balanced
# fit_intercept         True
# fpr              0.0123491
# label                toxic
# naive-bayes              Y
# precision         0.857143
# tpr               0.692158
# trained                  Y
# Name: 19, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 110
# severe_toxic
# 268
# {'C': 0.27000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                        0.27
# ROC                  0.987226
# class_weight             None
# fit_intercept           False
# fpr                0.00189789
# label            severe_toxic
# naive-bayes                 N
# precision            0.565217
# tpr                      0.26
# trained                     Y
# Name: 268, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 111
# toxic
# 135
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                    0.35
# ROC              0.983816
# class_weight     balanced
# fit_intercept        True
# fpr              0.010129
# label               toxic
# naive-bayes             N
# precision         0.88513
# tpr              0.729099
# trained                 Y
# Name: 135, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 112
# insult
# 852
# {'C': 0.5, 'fit_intercept': True, 'class_weight': None}
# C                       0.5
# ROC                0.980014
# class_weight           None
# fit_intercept         False
# fpr              0.00713342
# label                insult
# naive-bayes               N
# precision          0.815385
# tpr                0.583843
# trained                   Y
# Name: 852, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 113
# identity_hate
# 1000
# {'C': 0.32000000000000001, 'fit_intercept': True, 'class_weight': None}
# C                         0.32
# ROC                   0.985033
# class_weight              None
# fit_intercept            False
# fpr                 0.00151774
# label            identity_hate
# naive-bayes                  Y
# precision             0.671233
# tpr                   0.340278
# trained                      Y
# Name: 1000, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 114
# insult
# 841
# {'C': 0.40000000000000002, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.4
# ROC                0.981436
# class_weight       balanced
# fit_intercept         False
# fpr              0.00812417
# label                insult
# naive-bayes               Y
# precision          0.802568
# tpr                0.611995
# trained                   Y
# Name: 841, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 115
# threat
# 531
# {'C': 0.001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                      0.001
# ROC                 0.982899
# class_weight        balanced
# fit_intercept           True
# fpr              0.000314327
# label                 threat
# naive-bayes                Y
# precision           0.642857
# tpr                     0.18
# trained                    Y
# Name: 531, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 116
# identity_hate
# 944
# {'C': 0.20000000000000001, 'fit_intercept': True, 'class_weight': None}
# C                          0.2
# ROC                   0.985765
# class_weight              None
# fit_intercept            False
# fpr                 0.00158098
# label            identity_hate
# naive-bayes                  Y
# precision             0.666667
# tpr                   0.347222
# trained                      Y
# Name: 944, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 117
# insult
# 706
# {'C': 0.001, 'fit_intercept': True, 'class_weight': None}
# C                     0.001
# ROC                0.963189
# class_weight           None
# fit_intercept          True
# fpr              0.00719947
# label                insult
# naive-bayes               Y
# precision          0.781563
# tpr                0.477356
# trained                   Y
# Name: 706, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 118
# toxic
# 71
# {'C': 0.20000000000000001, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.2
# ROC                0.984429
# class_weight       balanced
# fit_intercept          True
# fpr              0.00992091
# label                 toxic
# naive-bayes               N
# precision          0.888368
# tpr                0.737524
# trained                   Y
# Name: 71, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 119
# threat
# 565
# {'C': 0.029999999999999999, 'fit_intercept': True, 'class_weight': 'balanced'}
# C                       0.03
# ROC                 0.992543
# class_weight        balanced
# fit_intercept          False
# fpr              0.000565789
# label                 threat
# naive-bayes                N
# precision           0.678571
# tpr                     0.38
# trained                    Y
# Name: 565, dtype: object
# ==================================================
# done
# ===================================
# nb disabled
# 120
# identity_hate
# 1022
# {'C': 0.40000000000000002, 'fit_intercept': True, 'class_weight': None}
# C                          0.4
# ROC                   0.984352
# class_weight              None
# fit_intercept             True
# fpr                 0.00126478
# label            identity_hate
# naive-bayes                  N
# precision              0.68254
# tpr                   0.298611
# trained                      Y
# Name: 1022, dtype: object
# ==================================================
# done
# ===================================
# nb enabled
# 121
# severe_toxic
# 307
# {'C': 0.34999999999999998, 'fit_intercept': True, 'class_weight': 'balanced'}

# %%
df_svc.to_csv(PATH + 'svc_all_gridsearch_nonemoji_0306.csv', index=False)

# %%
for col in label_cols:
    print(df_svc[df_svc['label'] == col].sort_values(['ROC'], ascending = False).iloc[0])
    print('----------------------')
# Out:
# C                     0.1
# ROC              0.984741
# fpr            0.00978216
# label               toxic
# naive-bayes             N
# precision        0.890272
# tpr              0.741413
# trained                 Y
# Name: 5, dtype: object
# ----------------------
# C                      0.01
# ROC                0.989741
# fpr              0.00246726
# label          severe_toxic
# naive-bayes               N
# precision               0.5
# tpr                    0.26
# trained                   Y
# Name: 53, dtype: object
# ----------------------
# C                    0.05
# ROC              0.993175
# fpr            0.00536673
# label             obscene
# naive-bayes             N
# precision        0.887344
# tpr              0.738426
# trained                 Y
# Name: 107, dtype: object
# ----------------------
# C                     0.01
# ROC               0.993429
# fpr            0.000502923
# label               threat
# naive-bayes              N
# precision         0.652174
# tpr                    0.3
# trained                  Y
# Name: 157, dtype: object
# ----------------------
# C                    0.05
# ROC              0.984656
# fpr            0.00739762
# label              insult
# naive-bayes             N
# precision        0.815486
# tpr              0.605875
# trained                 Y
# Name: 211, dtype: object
# ----------------------
# C                       0.01
# ROC                 0.987885
# fpr               0.00132802
# label          identity_hate
# naive-bayes                N
# precision           0.691176
# tpr                 0.326389
# trained                    Y
# Name: 261, dtype: object
# ----------------------

# %%
toxic = df_svc[df_svc['label'] == 'toxic']
toxic.sort_values(['ROC'], ascending = False)
# Out:
#        C       ROC       fpr  label naive-bayes  precision       tpr trained
# 5   0.10  0.984741  0.009782  toxic           N   0.890272  0.741413       Y
# 7   0.15  0.984702  0.009782  toxic           N   0.890272  0.741413       Y
# 9   0.20  0.984547  0.009574  toxic           N   0.892774  0.744653       Y
# 11  0.23  0.984433  0.009505  toxic           N   0.893136  0.742061       Y
# 13  0.25  0.984360  0.009366  toxic           N   0.894283  0.740117       Y
# 3   0.05  0.984300  0.009782  toxic           N   0.889844  0.738172       Y
# 15  0.27  0.984286  0.009366  toxic           N   0.893701  0.735580       Y
# 17  0.28  0.984246  0.009297  toxic           N   0.894322  0.734932       Y
# 19  0.29  0.984205  0.009297  toxic           N   0.894155  0.733636       Y
# 21  0.30  0.984172  0.009297  toxic           N   0.894155  0.733636       Y
# 23  0.32  0.984092  0.009297  toxic           N   0.893987  0.732340       Y
# 25  0.35  0.983978  0.009505  toxic           N   0.891956  0.732988       Y
# 27  0.40  0.983795  0.009366  toxic           N   0.892942  0.729747       Y
# 29  0.50  0.983450  0.009505  toxic           N   0.891356  0.728451       Y
# 6   0.15  0.983134  0.009574  toxic           Y   0.891934  0.738172       Y
# 4   0.10  0.983090  0.009990  toxic           Y   0.887850  0.738820       Y
# 8   0.20  0.983015  0.009435  toxic           Y   0.892998  0.735580       Y
# 10  0.23  0.982920  0.009435  toxic           Y   0.892913  0.734932       Y
# 31  0.70  0.982896  0.009435  toxic           N   0.891978  0.727803       Y
# 12  0.25  0.982845  0.009227  toxic           Y   0.894862  0.733636       Y
# 14  0.27  0.982759  0.009158  toxic           Y   0.895570  0.733636       Y
# 16  0.28  0.982713  0.009227  toxic           Y   0.894778  0.732988       Y
# 18  0.29  0.982673  0.009227  toxic           Y   0.894528  0.731043       Y
# 20  0.30  0.982632  0.009158  toxic           Y   0.895404  0.732340       Y
# 22  0.32  0.982549  0.009158  toxic           Y   0.895404  0.732340       Y
# 33  0.90  0.982456  0.009366  toxic           N   0.892259  0.724563       Y
# 24  0.35  0.982436  0.009088  toxic           Y   0.895866  0.730395       Y
# 2   0.05  0.982279  0.010268  toxic           Y   0.885004  0.738172       Y
# 35  1.00  0.982270  0.009297  toxic           N   0.892886  0.723914       Y
# 26  0.40  0.982246  0.009019  toxic           Y   0.896249  0.727803       Y
# 28  0.50  0.981880  0.009158  toxic           Y   0.894231  0.723266       Y
# 37  1.50  0.981570  0.009297  toxic           N   0.891935  0.716785       Y
# 1   0.01  0.981391  0.010060  toxic           N   0.884370  0.718730       Y
# 30  0.70  0.981270  0.008950  toxic           Y   0.895631  0.717434       Y
# 39  2.00  0.981103  0.009297  toxic           N   0.891586  0.714193       Y
# 32  0.90  0.980806  0.008950  toxic           Y   0.894780  0.710953       Y
# 34  1.00  0.980613  0.008880  toxic           Y   0.895254  0.709008       Y
# 41  3.00  0.980528  0.009158  toxic           N   0.892683  0.711601       Y
# 43  4.00  0.980187  0.009158  toxic           N   0.892245  0.708360       Y
# 45  5.00  0.979944  0.009158  toxic           N   0.891892  0.705768       Y
# 36  1.50  0.979897  0.008811  toxic           Y   0.895902  0.708360       Y
# 47  6.00  0.979771  0.009019  toxic           N   0.892828  0.701879       Y
# 49  7.00  0.979635  0.009088  toxic           N   0.892181  0.702528       Y
# 51  8.00  0.979537  0.009088  toxic           N   0.892181  0.702528       Y
# 38  2.00  0.979397  0.008533  toxic           Y   0.898599  0.706416       Y
# 40  3.00  0.978773  0.008464  toxic           Y   0.899007  0.703824       Y
# 42  4.00  0.978397  0.008533  toxic           Y   0.898010  0.701879       Y
# 44  5.00  0.978151  0.008603  toxic           Y   0.897181  0.701231       Y
# 46  6.00  0.977972  0.008325  toxic           Y   0.899917  0.699287       Y
# 48  7.00  0.977820  0.008256  toxic           Y   0.900585  0.698639       Y
# 50  8.00  0.977708  0.008256  toxic           Y   0.900502  0.697991       Y
# 0   0.01  0.975405  0.011239  toxic           Y   0.868720  0.694750       Y

# %%
###### naive bayes is N

params = {}
for col in label_cols:
    dff = df_svc[df_svc['naive-bayes'] == 'N']
    dff = dff[dff['label'] == col]
    params[col] = dff.sort_values(['ROC'], ascending = False).iloc[0]['C']

# %%
###### naive bayes is N

params = {col:{} for col in label_cols}
for col in label_cols:
    dff = df_svc[df_svc['naive-bayes'] == 'N']
    dff = dff[dff['label'] == col]
    best = dff.sort_values(['ROC'], ascending = False).iloc[0]
    params[col]['C'] = best['C']
    params[col]['fit_intercept'] = best['fit_intercept']
    params[col]['class_weight'] = best['class_weight']
    params[col]['fit_intercept'] = bool( params[col]['fit_intercept'])
    if params[col]['class_weight'] is 'balanced':
        params[col]['class_weight'] = 'balanced'
    else:
        params[col]['class_weight'] = None

# %%
params
# Out:
# {'identity_hate': 0.01,
#  'insult': 0.050000000000000003,
#  'obscene': 0.050000000000000003,
#  'severe_toxic': 0.01,
#  'threat': 0.01,
#  'toxic': 0.10000000000000001}

# %%
#### based on ROC no naive bayes
#0.9814
# {'identity_hate': 0.01,
#  'insult': 0.050000000000000003,
#  'obscene': 0.050000000000000003,
#  'severe_toxic': 0.01,
#  'threat': 0.01,
#  'toxic': 0.10000000000000001}

pred_prob = pd.DataFrame()
pred_prob['id'] = test['id']
for col in label_cols:
    lsvc = LinearSVC(C=params[col])
    model_svc = CalibratedClassifierCV(lsvc)
    model_svc.fit(train_tfidf, train[col].values)
    pred_prob[col] = model_svc.predict_proba(test_tfidf)[:,1]
pred_prob.to_csv(PATH + 'SVC_no_bayes_BEST_ROC_noemoji.csv', index=False)

# %%
params_nb = {}
for col in label_cols:
    dff = df_svc[df_svc['naive-bayes'] == 'Y']
    dff = dff[dff['label'] == col]
    params_nb[col] = dff.sort_values(['ROC'], ascending = False).iloc[0]['C']

# %%
params_nb
# Out:
# {'identity_hate': 0.10000000000000001,
#  'insult': 0.050000000000000003,
#  'obscene': 0.10000000000000001,
#  'severe_toxic': 0.050000000000000003,
#  'threat': 0.10000000000000001,
#  'toxic': 0.14999999999999999}

# %%
pred_prob = pd.DataFrame()
pred_prob['id'] = test['id']
for col in label_cols:
    print(col)
    lsvc = LinearSVC(C=params_nb[col])
    model_svc = CalibratedClassifierCV(lsvc)
    model_svc.fit(train_tfidf.multiply(r_dict[col]).tocsr(), train[col].values)
    pred_prob[col] = model_svc.predict_proba(test_tfidf.multiply(r_dict[col]).tocsr())[:,1]
pred_prob.to_csv(PATH + 'SVC_bayes_BEST_ROC_noemoji.csv', index=False)
# Out:
# toxic
# severe_toxic
# obscene
# threat
# insult
# identity_hate

# %%
df_svc
# Out:
#         C       ROC       fpr          label naive-bayes  precision       tpr  \
# 0    0.01  0.975405  0.011239          toxic           Y   0.868720  0.694750
# 1    0.01  0.981391  0.010060          toxic           N   0.884370  0.718730
# 2    0.05  0.982279  0.010268          toxic           Y   0.885004  0.738172
# 3    0.05  0.984300  0.009782          toxic           N   0.889844  0.738172
# 4    0.10  0.983090  0.009990          toxic           Y   0.887850  0.738820
# 5    0.10  0.984741  0.009782          toxic           N   0.890272  0.741413
# 6    0.15  0.983134  0.009574          toxic           Y   0.891934  0.738172
# 7    0.15  0.984702  0.009782          toxic           N   0.890272  0.741413
# 8    0.20  0.983015  0.009435          toxic           Y   0.892998  0.735580
# 9    0.20  0.984547  0.009574          toxic           N   0.892774  0.744653
# 10   0.23  0.982920  0.009435          toxic           Y   0.892913  0.734932
# 11   0.23  0.984433  0.009505          toxic           N   0.893136  0.742061
# 12   0.25  0.982845  0.009227          toxic           Y   0.894862  0.733636
# 13   0.25  0.984360  0.009366          toxic           N   0.894283  0.740117
# 14   0.27  0.982759  0.009158          toxic           Y   0.895570  0.733636
# 15   0.27  0.984286  0.009366          toxic           N   0.893701  0.735580
# 16   0.28  0.982713  0.009227          toxic           Y   0.894778  0.732988
# 17   0.28  0.984246  0.009297          toxic           N   0.894322  0.734932
# 18   0.29  0.982673  0.009227          toxic           Y   0.894528  0.731043
# 19   0.29  0.984205  0.009297          toxic           N   0.894155  0.733636
# 20   0.30  0.982632  0.009158          toxic           Y   0.895404  0.732340
# 21   0.30  0.984172  0.009297          toxic           N   0.894155  0.733636
# 22   0.32  0.982549  0.009158          toxic           Y   0.895404  0.732340
# 23   0.32  0.984092  0.009297          toxic           N   0.893987  0.732340
# 24   0.35  0.982436  0.009088          toxic           Y   0.895866  0.730395
# 25   0.35  0.983978  0.009505          toxic           N   0.891956  0.732988
# 26   0.40  0.982246  0.009019          toxic           Y   0.896249  0.727803
# 27   0.40  0.983795  0.009366          toxic           N   0.892942  0.729747
# 28   0.50  0.981880  0.009158          toxic           Y   0.894231  0.723266
# 29   0.50  0.983450  0.009505          toxic           N   0.891356  0.728451
# ..    ...       ...       ...            ...         ...        ...       ...
# 282  0.32  0.985033  0.001518  identity_hate           Y   0.671233  0.340278
# 283  0.32  0.984749  0.001265  identity_hate           N   0.687500  0.305556
# 284  0.35  0.984874  0.001518  identity_hate           Y   0.666667  0.333333
# 285  0.35  0.984583  0.001265  identity_hate           N   0.687500  0.305556
# 286  0.40  0.984594  0.001518  identity_hate           Y   0.661972  0.326389
# 287  0.40  0.984352  0.001265  identity_hate           N   0.682540  0.298611
# 288  0.50  0.984125  0.001518  identity_hate           Y   0.666667  0.333333
# 289  0.50  0.984024  0.001328  identity_hate           N   0.671875  0.298611
# 290  0.70  0.983299  0.001391  identity_hate           Y   0.685714  0.333333
# 291  0.70  0.983553  0.001328  identity_hate           N   0.676923  0.305556
# 292  0.90  0.982700  0.001328  identity_hate           Y   0.691176  0.326389
# 293  0.90  0.983285  0.001328  identity_hate           N   0.676923  0.305556
# 294  1.00  0.982440  0.001328  identity_hate           Y   0.691176  0.326389
# 295  1.00  0.983187  0.001328  identity_hate           N   0.676923  0.305556
# 296  1.50  0.981463  0.001265  identity_hate           Y   0.705882  0.333333
# 297  1.50  0.982837  0.001391  identity_hate           N   0.661538  0.298611
# 298  2.00  0.980834  0.001202  identity_hate           Y   0.703125  0.312500
# 299  2.00  0.982646  0.001328  identity_hate           N   0.671875  0.298611
# 300  3.00  0.980021  0.001012  identity_hate           Y   0.724138  0.291667
# 301  3.00  0.982444  0.001328  identity_hate           N   0.671875  0.298611
# 302  4.00  0.979538  0.001012  identity_hate           Y   0.709091  0.270833
# 303  4.00  0.982297  0.001265  identity_hate           N   0.677419  0.291667
# 304  5.00  0.979191  0.001012  identity_hate           Y   0.709091  0.270833
# 305  5.00  0.982170  0.001202  identity_hate           N   0.677966  0.277778
# 306  6.00  0.978961  0.001075  identity_hate           Y   0.690909  0.263889
# 307  6.00  0.982040  0.001202  identity_hate           N   0.677966  0.277778
# 308  7.00  0.978737  0.001075  identity_hate           Y   0.685185  0.256944
# 309  7.00  0.981972  0.001202  identity_hate           N   0.677966  0.277778
# 310  8.00  0.978553  0.001075  identity_hate           Y   0.685185  0.256944
# 311  8.00  0.981895  0.001202  identity_hate           N   0.677966  0.277778
#
#     trained
# 0         Y
# 1         Y
# 2         Y
# 3         Y
# 4         Y
# 5         Y
# 6         Y
# 7         Y
# 8         Y
# 9         Y
# 10        Y
# 11        Y
# 12        Y
# 13        Y
# 14        Y
# 15        Y
# 16        Y
# 17        Y
# 18        Y
# 19        Y
# 20        Y
# 21        Y
# 22        Y
# 23        Y
# 24        Y
# 25        Y
# 26        Y
# 27        Y
# 28        Y
# 29        Y
# ..      ...
# 282       Y
# 283       Y
# 284       Y
# 285       Y
# 286       Y
# 287       Y
# 288       Y
# 289       Y
# 290       Y
# 291       Y
# 292       Y
# 293       Y
# 294       Y
# 295       Y
# 296       Y
# 297       Y
# 298       Y
# 299       Y
# 300       Y
# 301       Y
# 302       Y
# 303       Y
# 304       Y
# 305       Y
# 306       Y
# 307       Y
# 308       Y
# 309       Y
# 310       Y
# 311       Y
#
# [312 rows x 8 columns]

# %%
df_svc = pd.read_csv(PATH + 'svc_all_gridsearch_nonemoji.csv')

# %%
label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
dd = df_svc[df_svc['label'] == 'threat']

# %%
dd.sort_values(['ROC'], ascending = False)
# Out:
#         C       ROC       fpr   label naive-bayes  precision   tpr trained
# 157  0.01  0.993429  0.000503  threat           N   0.652174  0.30       Y
# 160  0.10  0.993317  0.000566  threat           Y   0.640000  0.32       Y
# 162  0.15  0.993199  0.000566  threat           Y   0.653846  0.34       Y
# 164  0.20  0.992964  0.000566  threat           Y   0.653846  0.34       Y
# 158  0.05  0.992940  0.000629  threat           Y   0.615385  0.32       Y
# 166  0.23  0.992843  0.000503  threat           Y   0.680000  0.34       Y
# 168  0.25  0.992733  0.000503  threat           Y   0.680000  0.34       Y
# 170  0.27  0.992659  0.000566  threat           Y   0.653846  0.34       Y
# 172  0.28  0.992598  0.000566  threat           Y   0.666667  0.36       Y
# 174  0.29  0.992552  0.000566  threat           Y   0.666667  0.36       Y
# 176  0.30  0.992501  0.000566  threat           Y   0.666667  0.36       Y
# 178  0.32  0.992416  0.000566  threat           Y   0.666667  0.36       Y
# 180  0.35  0.992252  0.000566  threat           Y   0.666667  0.36       Y
# 159  0.05  0.992129  0.000503  threat           N   0.714286  0.40       Y
# 182  0.40  0.991995  0.000566  threat           Y   0.653846  0.34       Y
# 184  0.50  0.991488  0.000566  threat           Y   0.678571  0.38       Y
# 161  0.10  0.991106  0.000440  threat           N   0.740741  0.40       Y
# 186  0.70  0.990719  0.000440  threat           Y   0.730769  0.38       Y
# 163  0.15  0.990593  0.000440  threat           N   0.730769  0.38       Y
# 165  0.20  0.990270  0.000440  threat           N   0.730769  0.38       Y
# 188  0.90  0.990245  0.000440  threat           Y   0.720000  0.36       Y
# 167  0.23  0.990110  0.000440  threat           N   0.730769  0.38       Y
# 190  1.00  0.990016  0.000440  threat           Y   0.720000  0.36       Y
# 169  0.25  0.989999  0.000440  threat           N   0.730769  0.38       Y
# 171  0.27  0.989895  0.000440  threat           N   0.730769  0.38       Y
# 173  0.28  0.989835  0.000440  threat           N   0.730769  0.38       Y
# 175  0.29  0.989797  0.000440  threat           N   0.730769  0.38       Y
# 177  0.30  0.989753  0.000440  threat           N   0.730769  0.38       Y
# 179  0.32  0.989647  0.000440  threat           N   0.730769  0.38       Y
# 181  0.35  0.989498  0.000440  threat           N   0.730769  0.38       Y
# 183  0.40  0.989299  0.000440  threat           N   0.730769  0.38       Y
# 192  1.50  0.989229  0.000440  threat           Y   0.730769  0.38       Y
# 156  0.01  0.989136  0.000692  threat           Y   0.560000  0.28       Y
# 185  0.50  0.988912  0.000440  threat           N   0.720000  0.36       Y
# 194  2.00  0.988692  0.000440  threat           Y   0.720000  0.36       Y
# 187  0.70  0.988225  0.000440  threat           N   0.720000  0.36       Y
# 196  3.00  0.988059  0.000440  threat           Y   0.720000  0.36       Y
# 189  0.90  0.987682  0.000440  threat           N   0.720000  0.36       Y
# 198  4.00  0.987656  0.000440  threat           Y   0.708333  0.34       Y
# 200  5.00  0.987418  0.000440  threat           Y   0.708333  0.34       Y
# 191  1.00  0.987412  0.000440  threat           N   0.720000  0.36       Y
# 202  6.00  0.987255  0.000440  threat           Y   0.708333  0.34       Y
# 204  7.00  0.987123  0.000440  threat           Y   0.708333  0.34       Y
# 206  8.00  0.986991  0.000440  threat           Y   0.695652  0.32       Y
# 193  1.50  0.986289  0.000440  threat           N   0.720000  0.36       Y
# 195  2.00  0.985279  0.000440  threat           N   0.720000  0.36       Y
# 197  3.00  0.983826  0.000440  threat           N   0.720000  0.36       Y
# 199  4.00  0.982676  0.000440  threat           N   0.720000  0.36       Y
# 201  5.00  0.981855  0.000377  threat           N   0.739130  0.34       Y
# 203  6.00  0.980974  0.000377  threat           N   0.739130  0.34       Y
# 205  7.00  0.980494  0.000377  threat           N   0.739130  0.34       Y
# 207  8.00  0.980230  0.000377  threat           N   0.739130  0.34       Y

# %%
count = {}
for col in label_cols:
    count[col] = train[col].values.sum()

# %%
count
# Out:
# {'identity_hate': 1405,
#  'insult': 7877,
#  'obscene': 8449,
#  'severe_toxic': 1595,
#  'threat': 478,
#  'toxic': 15294}

# %%
df_svc_one = pd.read_csv(PATH + 'OneVsOne_svm_parameters.csv')

# %%
label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
ddd = df_svc_one[df_svc_one['label'] == 'toxic']
ddd.sort_values(['ROC'], ascending = False)
# Out:
#        C       ROC       fpr  label  precision       tpr
# 9   0.29  0.984275  0.052657  toxic   0.651994  0.921581
# 11  0.32  0.984274  0.052588  toxic   0.652134  0.920933
# 10  0.30  0.984273  0.052796  toxic   0.651397  0.921581
# 8   0.28  0.984271  0.052865  toxic   0.651259  0.922229
# 12  0.35  0.984271  0.052518  toxic   0.652593  0.921581
# 7   0.27  0.984266  0.052865  toxic   0.651259  0.922229
# 6   0.25  0.984257  0.052657  toxic   0.651675  0.920285
# 13  0.40  0.984257  0.052518  toxic   0.652593  0.921581
# 5   0.23  0.984230  0.052935  toxic   0.650160  0.918989
# 14  0.50  0.984207  0.053004  toxic   0.650663  0.922229
# 4   0.20  0.984175  0.053351  toxic   0.648377  0.918989
# 15  0.70  0.984081  0.053698  toxic   0.647701  0.922229
# 3   0.15  0.984012  0.053906  toxic   0.646497  0.920933
# 16  0.90  0.983955  0.053906  toxic   0.646818  0.922229
# 17  1.00  0.983894  0.054114  toxic   0.645777  0.921581
# 2   0.10  0.983652  0.054183  toxic   0.644839  0.918989
# 1   0.05  0.982600  0.055432  toxic   0.638625  0.915100
# 0   0.01  0.978360  0.057375  toxic   0.626805  0.900194

# %%
ddd
# Out:
# Empty DataFrame
# Columns: [C, ROC, fpr, label, precision, tpr]
# Index: []
